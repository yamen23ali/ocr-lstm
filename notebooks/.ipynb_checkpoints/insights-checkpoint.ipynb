# %%
import sys
sys.path.append('../src')

import os
import torch
import glob
import numpy as np
import torch.optim as optim
import torch.nn.functional as F

from ocr_data_loader import *
from ocr_utils import *
from ocr_image_transformations import *
from ocr_model import OCRModel
import matplotlib.pyplot as plt
from torchvision import transforms
from torch import nn
import torchvision
from PIL import Image
import torch
import torch.nn.functional as F
import numpy as np
import torch.optim as optim
import random
import time

from ocr_utils import *
from torch import nn

# %% [markdown]
# # Load & Predict
# load a model and get its predictions on the hold out book

# %%
BASE_DIR = '../../GT4HistOCR/corpus'
DATA_SET_NAME = 'RefCorpus-ENHG-Incunabula'
HOLDOUT_BOOK = '1499-CronicaCoellen'
MODEL_NAME = '17/model_3a20e32bea03553c26a0989a9ff9892d7dcd5918_dict'
FRAME_SIZE = 1
HIDDEN_LAYER_SIZE = 200
HIDDEN_LAYERS_NUM = 3
ALPHABET_SIZE = 92
BATCH_SIZE = 300

MAX_IMAGE_WIDTH=500
MAX_IMAGE_HEIGHT=20

INPUT_DIMENSION = MAX_IMAGE_HEIGHT * FRAME_SIZE

transformation = transforms.Compose([
    ImageThumbnail(MAX_IMAGE_HEIGHT, MAX_IMAGE_WIDTH),
    transforms.ToTensor(),
    ImageTensorPadding(MAX_IMAGE_HEIGHT, MAX_IMAGE_WIDTH),
    UnfoldImage(1, FRAME_SIZE)
])

train_data, test_data, holdout_data , dataset = load_data(base_dir = BASE_DIR, dataset_name = DATA_SET_NAME, 
                                           holdout_book = HOLDOUT_BOOK, transformation=transformation,
                                           batch_size=BATCH_SIZE, train_test_split=.8)

model = OCRModel(INPUT_DIMENSION, HIDDEN_LAYER_SIZE, HIDDEN_LAYERS_NUM, ALPHABET_SIZE)

state_dict = torch.load(f'../../models/RefCorpus-ENHG-Incunabula/{MODEL_NAME}.pth',
                       map_location=torch.device('cpu'))


model.load_state_dict(state_dict)
model.eval()
predictions = model.get_predictions(holdout_data, dataset.alphabet)
# Out:
# 1628
# 23148
# [[(0, 0.9918844578787684), (7, 0.9760336519102566), (8, 0.9989755073329434), (13, 0.993964928551577), (14, 0.9996547929476947), (15, 0.9959539253613912), (16, 0.9935071812942624), (22, 0.8535598069429398), (28, 0.9519692212246204), (29, 0.9989460408542072), (30, 0.9979445200879127), (31, 0.9993654423160478), (41, 0.9998372638074216), (46, 0.9467356167733669), (50, 0.9991445916821249), (55, 0.7960897982120514), (59, 0.9914934765547514), (66, 0.9928500717505813), (77, 0.9795659948140383), (84, 0.9462205090094358), (85, 0.9873765882803127), (86, 0.9755682237446308), (87, 0.9961175844073296), (93, 0.9710630010813475), (100, 0.9985534659354016), (104, 0.9932312215678394), (109, 0.9948132508434355), (110, 0.9951076568104327), (114, 0.9997530658729374), (119, 0.9995462321385276), (127, 0.9993256182060577), (131, 0.9617670513689518), (136, 0.9747321954928339), (137, 0.9597887694835663), (142, 0.9835121365904342), (143, 0.9673684984445572), (144, 0.9998597054509446), (148, 0.999474139069207), (154, 0.9998382500343723), (157, 0.9838831592351198), (161, 0.9668455103601445), (162, 0.9998905841639498), (166, 0.8688614517450333), (167, 0.7179550528526306), (169, 0.9872222077101469), (170, 0.9182855258695781), (171, 0.9865553816780448), (176, 0.9997957279265393), (177, 0.9998691
, 0.9199160779826343), (376, 0.9864546647295356), (384, 0.9559693587616493), (385, 0.912027396261692), (391, 0.933663562493166), (392, 0.8677097856998444), (401, 0.9996213037742336), (402, 0.9999970148062403), (403, 0.9802324645143017), (404, 0.9999699376367062), (411, 0.9999088985277922), (415, 0.9996245674265083), (421, 0.9970072314608842), (422, 0.994338077493012), (423, 0.9972726001869887), (428, 0.9995009195408784), (434, 0.9999390805060102), (441, 0.9727840553969145), (446, 0.9830903278561891), (447, 0.9997716765647056), (448, 0.9522307258703222), (449, 0.9998965495542507), (459, 0.9888055408373475), (466, 0.9967399630695581)], [(0, 0.9887404534965754), (12, 0.9998060826474102), (18, 0.9969937480054796), (19, 0.9960010224021971), (26, 0.8933968245983124), (27, 0.9996854538912885), (31, 0.9997316038352437), (35, 0.9974757151576341), (36, 0.9998442941141548), (42, 0.9900073539465666), (46, 0.9990511877695099), (50, 0.9942430066876113), (54, 0.9273852854967117), (56, 0.5925408005714417), (63, 0.9996192465769127), (69, 0.9544587900163606), (70, 0.9985744843725115), (73, 0.8722961246967316), (77, 0.9989598352694884), (83, 0.9999427941384056), (84, 0.9999202400576905), (85, 0.9943442439616774), (86, 0.9888112116605043), (92, 0.9966142326593399), (99, 0.989699681289494), (103, 0.9925489984452724), (108, 0.9994077327428386), (115, 0.999336069333367), (122, 0.990464692004025), (127, 0.9997623401868623), (128, 0.9586278485076 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-61b6c678fc0e> in <module>
#      33 model.load_state_dict(state_dict)
#      34 model.eval()
# ---> 35 predictions = model.get_predictions(holdout_data, dataset.alphabet)
#
# ~/Desktop/uni/Subjects/PJML/pml/src/ocr_model.py in get_predictions(self, data, alphabet)
#     127         for batch in enumerate(data):
#     128             true_texts = batch[1]['text']
# --> 129             predicted_texts, confidences = self.predict_batch(batch[1]['image'], alphabet)
#     130
#     131             for true_text, predicted_text, confidence in zip(true_texts, predicted_texts, confidences):
#
# ~/Desktop/uni/Subjects/PJML/pml/src/ocr_model.py in predict_batch(self, images_batch, alphabet)
#     110         """
#     111
# --> 112         output = self(images_batch.to(self.device)).cpu().detach().numpy()
#     113
#     114         return prob2text(output, alphabet), calculate_confidences(output)
#
# ~/miniconda3/envs/pjml/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/Desktop/uni/Subjects/PJML/pml/src/ocr_model.py in forward(self, x)
#      42         # We need to detach as we are doing truncated backpropagation through time (BPTT)
#      43         # If we don't, we'll backprop all the way to the start even after going through another batch
# ---> 44         out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
#      45
#      46         out = self.drop_out(out)
#
# ~/miniconda3/envs/pjml/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/pjml/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     562             return self.forward_packed(input, hx)
#     563         else:
# --> 564             return self.forward_tensor(input, hx)
#     565
#     566
#
# ~/miniconda3/envs/pjml/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward_tensor(self, input, hx)
#     541         unsorted_indices = None
#     542
# --> 543         output, hidden = self.forward_impl(input, hx, batch_sizes, max_batch_size, sorted_indices)
#     544
#     545         return output, self.permute_hidden(hidden, unsorted_indices)
#
# ~/miniconda3/envs/pjml/lib/python3.7/site-packages/torch/nn/modules/rnn.py in forward_impl(self, input, hx, batch_sizes, max_batch_size, sorted_indices)
#     524         if batch_sizes is None:
#     525             result = _VF.lstm(input, hx, self._get_flat_weights(), self.bias, self.num_layers,
# --> 526                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     527         else:
#     528             result = _VF.lstm(input, batch_sizes, hx, self._get_flat_weights(), self.bias,
#
# KeyboardInterrupt:

# %% [markdown]
# # Confidence

# %%
texts_confidence = np.array(predictions['texts_confidence'])
chars_confidence = np.array(predictions['chars_confidence'])
print(chars_confidence)
print(texts_confidence.min())
print(texts_confidence.max())
# Out:
# 0.7434437
# 0.99096787

# %% [markdown]
# # Confusion Matrix
# Calculate the confusion matrix on char level and report (Accuracy, Recall, Precision)

# %%
# use the blank as padding char since we don't care for it
padding_char = '$'

chars = { char : i for i,char in enumerate(dataset.alphabet) }

confusion = get_confusion_matrix(predictions['true_texts'], predictions['predicted_texts'], chars, padding_char)

tp = np.diag(confusion) # True positive
fp = confusion.sum(axis=0) - tp # False positive
fn = confusion.sum(axis=1) - tp # False negative
tn = confusion.trace() - tp # True negative

for char, i in chars.items():
    accuracy = (tp[i] + tn[i])/ (tp[i] + tn[i] + fp[i] + fn[i])
    recall = tp[i]/ (tp[i] + fn[i])
    precision = tp[i] / (tp[i] + fp[i])
    print(f'{char} : Accuracy {format(accuracy, ".2f")} - Recall {format(recall, ".2f")} - Precision {format(precision, ".2f")}')
# Out:
# 1628
# 993
# 40980.0
# 40980.0
# $ : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
#   : Accuracy 0.94 - Recall 0.84 - Precision 0.83
# 40980.0
# 40980.0
# ! : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# & : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# ( : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# ) : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# , : Accuracy 1.00 - Recall 0.00 - Precision nan
# 40980.0
# 40980.0
# . : Accuracy 0.99 - Recall 0.68 - Precision 0.77
# 40980.0
# 40980.0
# / : Accuracy 1.00 - Recall 0.47 - Precision 0.83
# 40980.0
# 40980.0
# 3 : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# 4 : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# : : Accuracy 1.00 - Recall nan - Precision 0.00
# 40980.0
# 40980.0
# ; : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# ? : Accuracy 1.00 - Recall 0.00 - Precision 0.00
# 40980.0
# 40980.0
# A : Accuracy 1.00 - Recall 0.64 - Precision 0.79
# 40980.0
# 40980.0
# B : Accuracy 1.00 - Recall 0.55 - Precision 0.73
# 40980.0
# 40980.0
# C : Accuracy 1.00 - Recall 0.76 - Precision 0.77
# 40980.0
# 40980.0
# D : Accuracy 1.00 - Recall 0.73 - Precision 0.71
# 40980.0
# 40980.0
# E : Accuracy 1.00 - Recall 0.88 - Precision 0.68
# 40980.0
# 40980.0
# F : Accuracy 1.00 - Recall 0.50 - Precision 0.71
# 40980.0
# 40980.0
# G : Accuracy 1.00 - Recall 0.70 - Precision 0.58
# 40980.0
# 40980.0
# H : Accuracy 1.00 - Recall 0.00 - Precision 0.00
# 40980.0
# 40980.0
# I : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# J : Accuracy 1.00 - Recall 0.79 - Precision 0.81
# 40980.0
# 40980.0
# K : Accuracy 1.00 - Recall 0.00 - Precision nan
# 40980.0
# 40980.0
# L : Accuracy 1.00 - Recall 0.20 - Precision 0.25
# 40980.0
# 40980.0
# M : Accuracy 1.00 - Recall 0.25 - Precision 0.91
# 40980.0
# 40980.0
# N : Accuracy 1.00 - Recall 0.53 - Precision 0.75
# 40980.0
# 40980.0
# O : Accuracy 1.00 - Recall 0.91 - Precision 0.77
# 40980.0
# 40980.0
# P : Accuracy 1.00 - Recall 0.86 - Precision 0.86
# 40980.0
# 40980.0
# Q : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# R : Accuracy 1.00 - Recall 0.81 - Precision 0.71
# 40980.0
# 40980.0
# S : Accuracy 1.00 - Recall 0.80 - Precision 0.72
# 40980.0
# 40980.0
# T : Accuracy 1.00 - Recall 0.38 - Precision 0.75
# 40980.0
# 40980.0
# U : Accuracy 1.00 - Recall 0.00 - Precision nan
# 40980.0
# 40980.0
# V : Accuracy 1.00 - Recall 0.96 - Precision 0.81
# 40980.0
# 40980.0
# W : Accuracy 1.00 - Recall 0.82 - Precision 0.88
# 40980.0
# 40980.0
# X : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# Y : Accuracy 1.00 - Recall nan - Precision 0.00
# 40980.0
# 40980.0
# Z : Accuracy 1.00 - Recall 0.00 - Precision 0.00
# 40980.0
# 40980.0
# a : Accuracy 0.98 - Recall 0.84 - Precision 0.85
# 40980.0
# 40980.0
# b : Accuracy 1.00 - Recall 0.81 - Precision 0.82
# 40980.0
# 40980.0
# c : Accuracy 0.99 - Recall 0.84 - Precision 0.83
# 40980.0
# 40980.0
# d : Accuracy 0.98 - Recall 0.83 - Precision 0.86
# 40980.0
# 40980.0
# e : Accuracy 0.96 - Recall 0.84 - Precision 0.85
# 40980.0
# 40980.0
# f : Accuracy 1.00 - Recall 0.88 - Precision 0.88
# 40980.0
# 40980.0
# g : Accuracy 0.99 - Recall 0.85 - Precision 0.85
# 40980.0
# 40980.0
# h : Accuracy 0.99 - Recall 0.84 - Precision 0.84
# 40980.0
# 40980.0
# i : Accuracy 0.98 - Recall 0.84 - Precision 0.81
# 40980.0
# 40980.0
# j : Accuracy 1.00 - Recall 0.71 - Precision 0.83
# 40980.0
# 40980.0
# k : Accuracy 1.00 - Recall 0.81 - Precision 0.82
# 40980.0
# 40980.0
# l : Accuracy 0.99 - Recall 0.86 - Precision 0.84
# 40980.0
# 40980.0
# m : Accuracy 0.99 - Recall 0.83 - Precision 0.83
# 40980.0
# 40980.0
# n : Accuracy 0.97 - Recall 0.85 - Precision 0.86
# 40980.0
# 40980.0
# o : Accuracy 0.99 - Recall 0.83 - Precision 0.82
# 40980.0
# 40980.0
# p : Accuracy 1.00 - Recall 0.82 - Precision 0.86
# 40980.0
# 40980.0
# q : Accuracy 1.00 - Recall 0.68 - Precision 0.79
# 40980.0
# 40980.0
# r : Accuracy 0.98 - Recall 0.82 - Precision 0.85
# 40980.0
# 40980.0
# s : Accuracy 1.00 - Recall 0.83 - Precision 0.83
# 40980.0
# 40980.0
# t : Accuracy 0.98 - Recall 0.85 - Precision 0.81
# 40980.0
# 40980.0
# u : Accuracy 0.99 - Recall 0.85 - Precision 0.83
# 40980.0
# 40980.0
# v : Accuracy 0.99 - Recall 0.85 - Precision 0.85
# 40980.0
# 40980.0
# w : Accuracy 1.00 - Recall 0.88 - Precision 0.89
# 40980.0
# 40980.0
# x : Accuracy 1.00 - Recall 0.58 - Precision 0.76
# 40980.0
# 40980.0
# y : Accuracy 0.99 - Recall 0.86 - Precision 0.85
# 40980.0
# 40980.0
# z : Accuracy 1.00 - Recall 0.82 - Precision 0.81
# 40980.0
# 40980.0
# ¶ : Accuracy 1.00 - Recall 0.96 - Precision 0.79
# 40980.0
# 40980.0
# · : Accuracy 1.00 - Recall nan - Precision 0.00
# 40980.0
# 40980.0
# ß : Accuracy 1.00 - Recall 0.93 - Precision 0.78
# 40980.0
# 40980.0
# ã : Accuracy 1.00 - Recall 0.79 - Precision 0.71
# 40980.0
# 40980.0
# ä : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# ð : Accuracy 1.00 - Recall 0.82 - Precision 0.83
# 40980.0
# 40980.0
# ñ : Accuracy 1.00 - Recall 0.79 - Precision 0.60
# 40980.0
# 40980.0
# õ : Accuracy 1.00 - Recall 1.00 - Precision 1.00
# 40980.0
# 40980.0
# ö : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# ü : Accuracy 1.00 - Recall nan - Precision 0.00
# 40980.0
# 40980.0
# ÿ : Accuracy 1.00 - Recall nan - Precision 0.00
# 40980.0
# 40980.0
# ĩ : Accuracy 1.00 - Recall 0.00 - Precision nan
# 40980.0
# 40980.0
# ũ : Accuracy 1.00 - Recall 0.50 - Precision 0.78
# 40980.0
# 40980.0
# ů : Accuracy 1.00 - Recall nan - Precision 0.00
# 40980.0
# 40980.0
# ſ : Accuracy 0.99 - Recall 0.85 - Precision 0.85
# 40980.0
# 40980.0
# ̃ : Accuracy 1.00 - Recall 0.00 - Precision nan
# 40980.0
# 40980.0
# ̈ : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# ͤ : Accuracy 1.00 - Recall nan - Precision 0.00
# 40980.0
# 40980.0
# ᷣ : Accuracy 1.00 - Recall 1.00 - Precision 1.00
# 40980.0
# 40980.0
# ṽ : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# ẽ : Accuracy 1.00 - Recall 0.85 - Precision 0.73
# 40980.0
# 40980.0
# ỹ : Accuracy 1.00 - Recall 0.31 - Precision 0.75
# 40980.0
# 40980.0
# ⸗ : Accuracy 1.00 - Recall 1.00 - Precision 0.04
# 40980.0
# 40980.0
# ꝓ : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# ꝭ : Accuracy 1.00 - Recall nan - Precision nan
# 40980.0
# 40980.0
# ꝰ : Accuracy 1.00 - Recall 0.00 - Precision nan
# /Users/d070867/miniconda3/envs/pjml/lib/python3.7/site-packages/ipykernel_launcher.py:38: RuntimeWarning: invalid value encountered in double_scalars
# /Users/d070867/miniconda3/envs/pjml/lib/python3.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning: invalid value encountered in double_scalars

# %%
DATA_SET_NAME = 'EarlyModernLatin'
HOLDOUT_BOOK = '1483-Decades-Biondo'
MODEL_NAME = '1_150_2/model_1_150_2_50_dict'
FRAME_SIZE = 1
HIDDEN_LAYER_SIZE = 150
HIDDEN_LAYERS_NUM = 2
ALPHABET_SIZE = 181
BATCH_SIZE = 300

MAX_IMAGE_WIDTH=1657
MAX_IMAGE_HEIGHT=50

INPUT_DIMENSION = MAX_IMAGE_HEIGHT * FRAME_SIZE

transformation = transforms.Compose([
    ImageThumbnail(MAX_IMAGE_HEIGHT, MAX_IMAGE_WIDTH),
    transforms.ToTensor(),
    ImageTensorPadding(MAX_IMAGE_HEIGHT, MAX_IMAGE_WIDTH),
    UnfoldImage(1, FRAME_SIZE)
])

train_data, test_data, holdout_data , dataset = load_data(base_dir = BASE_DIR, dataset_name = DATA_SET_NAME, 
                                           holdout_book = HOLDOUT_BOOK, transformation=transformation,
                                           batch_size=BATCH_SIZE, train_test_split=.8)

model = OCRModel(INPUT_DIMENSION, HIDDEN_LAYER_SIZE, HIDDEN_LAYERS_NUM, ALPHABET_SIZE)

state_dict = torch.load(f'../../models/EarlyModelLatin/{MODEL_NAME}.pth',
                       map_location=torch.device('cpu'))


model.load_state_dict(state_dict)
model.eval()
predictions = model.get_predictions(holdout_data, dataset.alphabet)
